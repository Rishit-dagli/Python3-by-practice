# %% [markdown]
# # Support Vector Machine
#
# _Notebook orignially contributed by: [taneemishere](https://github.com/taneemishere)_
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1dludIBnkaHc1AyMXJ1IqoGa9RpgDUN9I?usp=sharing"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Rishit-dagli/Python3-by-practice/blob/master/Machine%20Learning/sklearn%20examples/Support%20Vector%20Machine%20(SVM)/SVM%20.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# The following notebook uses a breast cancer dataset from USI machine learning repository that focuses on whether after seeing certain features, a patient has what type of cancer, i-e malignant or benign
# It is followed by a series of steps involving data reading the analysing, applying Machine Learning Algorithm the SVM Classifier and then printing out the accuracy score of this classifier.
#
# We use the <a href="https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)">Breast Canser Dataset</a>

# %% [markdown]
# ## Dataset Credit

# %% [markdown]
# Creators:
#
# 1. Dr. William H. Wolberg, General Surgery Dept.
# University of Wisconsin, Clinical Sciences Center
# Madison, WI 53792
# wolberg '@' eagle.surgery.wisc.edu
#
# 2. W. Nick Street, Computer Sciences Dept.
# University of Wisconsin, 1210 West Dayton St., Madison, WI 53706
# street '@' cs.wisc.edu 608-262-6619
#
# 3. Olvi L. Mangasarian, Computer Sciences Dept.
# University of Wisconsin, 1210 West Dayton St., Madison, WI 53706
# olvi '@' cs.wisc.edu
#
# Donor:
#
# Nick Street

# %% [markdown]
# ### Attribute Information:
#
# 1) ID number
# 2) Diagnosis (M = malignant, B = benign)
# 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# - a) radius (mean of distances from center to points on the perimeter)
# - b) texture (standard deviation of gray-scale values)
# - c) perimeter
# - d) area
# - e) smoothness (local variation in radius lengths)
# - f) compactness (perimeter^2 / area - 1.0)
# - g) concavity (severity of concave portions of the contour)
# - h) concave points (number of concave portions of the contour)
# - i) symmetry
# - j) fractal dimension ("coastline approximation" - 1)

# %% [markdown]
# #### Importing pandas and numpy

# %%
import pandas as pd
import numpy as np

# %%
# Reading the dataset with the pandas data frames
df = pd.read_csv('breast_cancer_data.csv')

# %%
# Drop these columns as we dont' need it because we've id which doesn't need for featuring also a column unnamed which doesn't have entries.
df = df.drop(['id', 'Unnamed: 32'], axis=1)

# %%
# See the first five entries of the dataset
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Now in the dataset we don't have any null valued column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
# see the dataset now
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ### Importing sklearn and some of it's important modules we needed

# %%
import sklearn
# svm ==> support vector machine
from sklearn import svm

# %%
from sklearn.model_selection import train_test_split
# For accuracy score
from sklearn import metrics

# %% [markdown]
# #### Features

# %%
# Drop the dignosis column from the rest as this is our label to predict
feartures = np.array(df.drop(['diagnosis'], 1))

# %% [markdown]
# #### Label

# %%
# Assign diagnosis to the label var
label = np.array(df['diagnosis'])

# %% [markdown]
# ### Split the datset
# Splitting the dataset into 80-20%, for training and testing respectively with the help of sklearn

# %%
# 20 % of the total data is assigned to the testing purpose
X_train, X_test, y_train, y_test = train_test_split(feartures, label, test_size=0.2)

# %% [markdown]
# ### Training the Model

# %%
# Soft margin for this linear kernel is 5
clf = svm.SVC(kernel="linear", C=5)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=5, kernel='linear')

# %% [markdown]
# #### Evalualtion and Prediction

# %%
accuracy = clf.score(X_test, y_test)
accuracy
# Out:
# 0.956140350877193

# %%
prediction = clf.predict(X_test)

# %%
prediction
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M',
#        'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M'], dtype=object)

# %%
acc = metrics.accuracy_score(y_test, prediction)

# %%
acc
# Out:
# 0.9473684210526315
